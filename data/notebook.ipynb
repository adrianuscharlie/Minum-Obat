# %%
import pandas as pd

# %%
df=pd.read_csv('record.csv')
df
# Out:
#           jadwal_konsumsi              jam_konsumsi                nama  \
# 0    2022-06-25T02:00:00Z  2022-06-26T08:03:20.077Z                IbuC
# 1    2022-06-25T05:00:00Z  2022-06-26T08:03:20.740Z                IbuC
# 2    2022-06-25T08:00:00Z  2022-06-26T08:03:21.245Z                IbuC
# 3    2022-06-26T02:00:00Z  2022-06-26T08:03:21.729Z                IbuC
# 4    2022-06-26T05:00:00Z  2022-06-26T08:03:22.179Z                IbuC
# ..                    ...                       ...                 ...
# 154  2022-08-18T11:00:00Z  2022-08-18T12:16:16.657Z     SETYONO YOHANES
# 155  2022-07-20T11:00:00Z  2022-07-20T12:09:14.212Z     SETYONO YOHANES
# 156  2022-08-27T11:00:00Z  2022-08-27T12:12:54.698Z     SETYONO YOHANES
# 157  2022-08-15T11:00:00Z  2022-08-15T12:05:30.726Z     SETYONO YOHANES
# 158  2022-07-17T23:00:00Z  2022-07-17T23:49:29.569Z  Yulia Betty Murias
#
#              nama_obat  telat  \
# 0            Metformin   True
# 1            Metformin   True
# ...

# %%
df=df[['jadwal_konsumsi','jam_konsumsi','nama','nama_obat','telat']]
df
# Out:
#           jadwal_konsumsi              jam_konsumsi                nama  \
# 0    2022-06-25T02:00:00Z  2022-06-26T08:03:20.077Z                IbuC
# 1    2022-06-25T05:00:00Z  2022-06-26T08:03:20.740Z                IbuC
# 2    2022-06-25T08:00:00Z  2022-06-26T08:03:21.245Z                IbuC
# 3    2022-06-26T02:00:00Z  2022-06-26T08:03:21.729Z                IbuC
# 4    2022-06-26T05:00:00Z  2022-06-26T08:03:22.179Z                IbuC
# ..                    ...                       ...                 ...
# 154  2022-08-18T11:00:00Z  2022-08-18T12:16:16.657Z     SETYONO YOHANES
# 155  2022-07-20T11:00:00Z  2022-07-20T12:09:14.212Z     SETYONO YOHANES
# 156  2022-08-27T11:00:00Z  2022-08-27T12:12:54.698Z     SETYONO YOHANES
# 157  2022-08-15T11:00:00Z  2022-08-15T12:05:30.726Z     SETYONO YOHANES
# 158  2022-07-17T23:00:00Z  2022-07-17T23:49:29.569Z  Yulia Betty Murias
#
#              nama_obat  telat
# 0            Metformin   True
# 1            Metformin   True
# ...

# %%
nama=df['nama'].unique()
nama=nama[2:]
nama
# Out:
# array(['ETTY ASTUTI', 'SETYONO YOHANES', 'Yulia Betty Murias'],
#       dtype=object)

# %%
for index,row in df.iterrows():
    if row['nama'] not in nama:
        
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Coding\Flutter\farmasi\data\notebook.ipynb Cell 5 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/Coding/Flutter/farmasi/data/notebook.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> for index,row in df.iterrows():
#       <a href='vscode-notebook-cell:/d%3A/Coding/Flutter/farmasi/data/notebook.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     if row['nama'] not in nama:
# ----> <a href='vscode-notebook-cell:/d%3A/Coding/Flutter/farmasi/data/notebook.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>         df.drop(df[[index]])
#       <a href='vscode-notebook-cell:/d%3A/Coding/Flutter/farmasi/data/notebook.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> df
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
# ...
